# %%
pip install -U langchain langchain-community langchain-chroma langchain-text-splitters chromadb pypdf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain in c:\users\jaybr\appdata\roaming\python\python313\site-packages (1.2.0)
# Requirement already satisfied: langchain-community in c:\users\jaybr\appdata\roaming\python\python313\site-packages (0.4.1)
# Requirement already satisfied: langchain-chroma in c:\users\jaybr\appdata\roaming\python\python313\site-packages (1.1.0)
# Requirement already satisfied: langchain-text-splitters in c:\users\jaybr\appdata\roaming\python\python313\site-packages (1.1.0)
# Requirement already satisfied: chromadb in c:\users\jaybr\appdata\roaming\python\python313\site-packages (1.4.0)
# Requirement already satisfied: pypdf in c:\users\jaybr\appdata\roaming\python\python313\site-packages (6.5.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain) (1.2.5)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.5.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.1->langchain) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.1->langchain) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.1)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.12.0)
# Requirement already satisfied: certifi in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-community) (2.4.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.1->langchain) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: build>=1.0.3 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (1.3.0)
# Requirement already satisfied: pybase64>=1.4.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (1.4.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.40.0)
# Requirement already satisfied: posthog<6.0.0,>=2.4.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (5.4.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (1.23.2)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (1.39.1)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (0.22.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (4.67.1)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (6.5.2)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (1.76.0)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (5.0.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (0.20.1)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (34.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (5.2.0)
# Requirement already satisfied: rich>=10.11.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (14.2.0)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from chromadb) (4.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.2 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from posthog<6.0.0,>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: pyproject_hooks in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: colorama in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from jsonschema>=4.19.0->chromadb) (0.30.0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.45.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (1.9.0)
# Requirement already satisfied: requests-oauthlib in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (2.0.0)
# Requirement already satisfied: durationpy>=0.7 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from kubernetes>=28.1.0->chromadb) (0.10)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (6.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9.1)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from rsa<5,>=3.1.4->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Requirement already satisfied: coloredlogs in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (25.12.19)
# Requirement already satisfied: protobuf in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (6.33.2)
# Requirement already satisfied: sympy in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from onnxruntime>=1.14.1->chromadb) (1.14.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from opentelemetry-api>=1.2.0->chromadb) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.23.0)
# Requirement already satisfied: googleapis-common-protos~=1.57 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.72.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.39.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-proto==1.39.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.39.1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.60b1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.60b1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from rich>=10.11.0->chromadb) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from tokenizers>=0.13.2->chromadb) (1.2.3)
# Requirement already satisfied: filelock in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.20.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (0.20.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from typer>=0.9.0->chromadb) (8.3.1)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.7.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.1.1)
# Requirement already satisfied: websockets>=10.4 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (15.0.1)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyreadline3 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb) (3.5.4)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from requests-oauthlib->kubernetes>=28.1.0->chromadb) (3.3.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install -U langchain-classic
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: langchain-classic in c:\users\jaybr\appdata\roaming\python\python313\site-packages (1.0.1)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.5 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-classic) (1.2.5)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-classic) (1.1.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-classic) (0.5.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-classic) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-classic) (6.0.3)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-classic) (2.32.5)
# Requirement already satisfied: sqlalchemy<3.0.0,>=1.4.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-classic) (2.0.45)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (25.0)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langchain-core<2.0.0,>=1.2.5->langchain-classic) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.5->langchain-classic) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from langsmith<1.0.0,>=0.1.17->langchain-classic) (0.25.0)
# Requirement already satisfied: anyio in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (4.12.0)
# Requirement already satisfied: certifi in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (1.0.9)
# Requirement already satisfied: idna in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.17->langchain-classic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from requests<3.0.0,>=2.0.0->langchain-classic) (2.3.0)
# Requirement already satisfied: greenlet>=1 in c:\users\jaybr\appdata\roaming\python\python313\site-packages (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaEmbeddings, ChatOllama
from langchain_chroma import Chroma
from langchain_classic.chains import create_retrieval_chain
from langchain_classic.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# -------------------- CONFIG --------------------
PDF_FILE = "C:/Users/jaybr/Downloads/RAG.pdf"
DB_DIR = "./rag_db"
EMBED_MODEL = "nomic-embed-text"
LLM_MODEL = "llama3.2"

# -------------------- LOAD PDF --------------------
loader = PyPDFLoader(PDF_FILE)
documents = loader.load()

# -------------------- SPLIT TEXT --------------------
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=300,
    separators=["\n\n", "\n", ".", " "]
)
chunks = text_splitter.split_documents(documents)

# -------------------- VECTOR STORE --------------------
embeddings = OllamaEmbeddings(model=EMBED_MODEL)
vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=DB_DIR
)

# -------------------- RETRIEVER --------------------
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k":15})

# -------------------- LLM --------------------
llm = ChatOllama(model=LLM_MODEL, temperature=0)

# -------------------- PDF-ONLY PROMPT --------------------
prompt = ChatPromptTemplate.from_messages([
    ("system",
     "You are a PDF question-answering assistant.\n"
     "Answer ONLY using the provided context below.\n"
     "Do NOT use any external knowledge or assumptions.\n"
     "If the answer is not in the context, say exactly:\n"
     "'I could not find the answer in the provided document.'\n\n"
     "Context:\n{context}"
    ),
    ("human", "{input}")
])

# -------------------- RAG CHAIN --------------------
qa_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(retriever, qa_chain)

# -------------------- QUERY --------------------
query = "Explain the results section in the PDF"

response = rag_chain.invoke({"input": query})

print("\n🤖 AI Answer (strictly PDF only):")
print(response["answer"])
# Out:
# 🤖 AI Answer (strictly PDF only):
# The Results section appears to be a table (Table 1) that presents the test scores for various models on two different datasets: Open-Domain QA and TQA-Wiki.
#
# Here's a breakdown of the table:
#
# **Columns:**
#
# * Model: The name of the model being evaluated.
# * NQ: The score for the Natural Question (NQ) dataset.
# * TQA: The score for the TQA (Task-Oriented Question Answering) dataset.
# * WQ: The score for the WikiQuestion (WQ) dataset.
# * CT: The score for the Closed-Book Test (CT).
#
# **Rows:**
#
# Each row represents a different model, with its corresponding scores on each of the four datasets.
#
# **Scores:**
#
# The scores are presented as percentages, indicating the percentage of correct answers or performance achieved by each model on each dataset. For example, T5-11B has a score of 34.5% on the NQ dataset and 37.4% on the CT dataset.
#
# **Models:**
#
# Some notable models mentioned in the table include:
#
# * T5-11B: A variant of the T5 model.
# * T5-11B+SSM: Another variant of the T5 model with additional self-supervised masking (SSM) training.
# * REALM: A model that achieved high scores on both NQ and WQ datasets.
# * DPR: A model that performed well on the TQA dataset.
# * RAG-Token and RAG-Seq.: Two models that used different tokenization strategies.
#
# Overall, the Results section appears to provide a comparison of various models' performance on different question answering datasets.

# %%
#without llm
import os
from langchain_community.document_loaders import PyPDFLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_ollama import OllamaEmbeddings
from langchain_chroma import Chroma

# ---------------- CONFIG ----------------
PDF_FILE = "C:/Users/jaybr/Downloads/RAG.pdf"
DB_DIR = "./rag_db"
EMBED_MODEL = "nomic-embed-text"

# ---------------- LOAD PDF ----------------
loader = PyPDFLoader(PDF_FILE)
documents = loader.load()

# ---------------- SPLIT TEXT ----------------
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=2000,
    chunk_overlap=300,
    separators=["\n\n", "\n", ".", " "]
)
chunks = text_splitter.split_documents(documents)

print(f"✅ Split PDF into {len(chunks)} chunks.")

# ---------------- VECTOR STORE ----------------
embeddings = OllamaEmbeddings(model=EMBED_MODEL)

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings,
    persist_directory=DB_DIR
)

# ---------------- RETRIEVE (NO LLM) ----------------
query = "Explain the results described in the PDF"

results = vectorstore.similarity_search(query, k=5)

print("\n📚 Retrieved chunks (NO LLM):\n")
for i, doc in enumerate(results, 1):
    print(f"--- Chunk {i} ---")
    print(doc.page_content)
    print("-" * 80)
# Out:
# ✅ Split PDF into 50 chunks.
#
# 📚 Retrieved chunks (NO LLM):
#
# --- Chunk 1 ---
# Table 2 shows that RAG-Token performs better than RAG-Sequence on Jeopardy question generation,
# with both models outperforming BART on Q-BLEU-1. 4 shows human evaluation results, over 452
# pairs of generations from BART and RAG-Token. Evaluators indicated that BART was more factual
# than RAG in only 7.1% of cases, while RAG was more factual in 42.7% of cases, and both RAG and
# BART were factual in a further 17% of cases, clearly demonstrating the effectiveness of RAG on
# --------------------------------------------------------------------------------
# --- Chunk 2 ---
# Table 2 shows that RAG-Token performs better than RAG-Sequence on Jeopardy question generation,
# with both models outperforming BART on Q-BLEU-1. 4 shows human evaluation results, over 452
# pairs of generations from BART and RAG-Token. Evaluators indicated that BART was more factual
# than RAG in only 7.1% of cases, while RAG was more factual in 42.7% of cases, and both RAG and
# BART were factual in a further 17% of cases, clearly demonstrating the effectiveness of RAG on
# --------------------------------------------------------------------------------
# --- Chunk 3 ---
# Table 1: Open-Domain QA Test Scores. For TQA,
# left column uses the standard test set for Open-
# Domain QA, right column uses the TQA-Wiki
# test set. See Appendix D for further details.
# Model NQ TQA WQ CT
# Closed
# Book
# T5-11B [52] 34.5 - /50.1 37.4 -
# T5-11B+SSM[52] 36.6 - /60.5 44.7 -
# Open
# Book
# REALM [20] 40.4 - / - 40.7 46.8
# DPR [26] 41.5 57.9/ - 41.1 50.6
# RAG-Token 44.1 55.2/66.1 45.5 50.0
# RAG-Seq. 44.5 56.8/68.0 45.2 52.2
# Table 2: Generation and classiﬁcation Test Scores.
# --------------------------------------------------------------------------------
# --- Chunk 4 ---
# Table 1: Open-Domain QA Test Scores. For TQA,
# left column uses the standard test set for Open-
# Domain QA, right column uses the TQA-Wiki
# test set. See Appendix D for further details.
# Model NQ TQA WQ CT
# Closed
# Book
# T5-11B [52] 34.5 - /50.1 37.4 -
# T5-11B+SSM[52] 36.6 - /60.5 44.7 -
# Open
# Book
# REALM [20] 40.4 - / - 40.7 46.8
# DPR [26] 41.5 57.9/ - 41.1 50.6
# RAG-Token 44.1 55.2/66.1 45.5 50.0
# RAG-Seq. 44.5 56.8/68.0 45.2 52.2
# Table 2: Generation and classiﬁcation Test Scores.
# --------------------------------------------------------------------------------
# --- Chunk 5 ---
# Appendices for Retrieval-Augmented Generation for
# Knowledge-Intensive NLP Tasks
# A Implementation Details
# For Open-domain QA we report test numbers using 15 retrieved documents for RAG-Token models.
# For RAG-Sequence models, we report test results using 50 retrieved documents, and we use the
# Thorough Decoding approach since answers are generally short. We use greedy decoding for QA as
# we did not ﬁnd beam search improved results. For Open-MSMarco and Jeopardy question generation,
# --------------------------------------------------------------------------------
